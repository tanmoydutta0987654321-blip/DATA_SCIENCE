# %%
import pandas as pd

# %%
print(pd.__version__)

# %%
data={
    "Name":["pikachu","Charmilian","froggy"],
    "type":["Eletric","Fire","Water"]
    }
df=pd.DataFrame(data)

print(df)

# %%
dataplay= pd.DataFrame(
        {
            ("a", "b"): {("A", "B"): 1, ("A", "C"): 2},
            ("a", "a"): {("A", "C"): 3, ("A", "B"): 4},
            ("a", "c"): {("A", "B"): 5, ("A", "C"): 6},
            ("b", "a"): {("A", "C"): 7, ("A", "B"): 8},
            ("b", "b"): {("A", "D"): 9, ("A", "B"): 10},
        }
    )
print(dataplay)

# %%
# data=pd.read_csv("pokemon.csv")
# print(data)
# df=data
# df["power"]=df["Total"]-5
# df.dropna()
# print(df)

# %%
del1=df.tail(2)

print(del1.dropna())
print(df)

# %%
# df=df.drop([1,2])
df["foo"] = "bar"
df["one_trunc"] = df["Name"][:2]
df.insert(1, "bar", df["Name"])
print(df)

# %%
data={
    "Name":['ram','sam','bheem','ram','kam'],
    "Age":[12,15,17,12,19],
    "Gender":["male","Female","Female","male","male"],
    "City":['Rishra','kolkata','naihati','noorpur','Diamond Hurbour'],
    "Sub1":[85,75,96,12,45],
    "Sub2":[75,48,92,74,88],
    "Sub3":[45,79,98,45,85]
}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Gender             City  Sub1  Sub2  Sub3
# 0    ram   12    male           Rishra    85    75    45
# 1    sam   15  Female          kolkata    75    48    79
# 2  bheem   17  Female          naihati    96    92    98
# 3    ram   12    male          noorpur    12    74    45
# 4    kam   19    male  Diamond Hurbour    45    88    85

# %%
df["Average"]=df[["Sub1","Sub2","Sub3"]].mean(axis=1)
print(df)
# Out:
#     Name  Age  Gender             City  Sub1  Sub2  Sub3    Average
# 0    ram   12    male           Rishra    85    75    45  68.333333
# 1    sam   15  Female          kolkata    75    48    79  67.333333
# 2  bheem   17  Female          naihati    96    92    98  95.333333
# 3    ram   12    male          noorpur    12    74    45  43.666667
# 4    kam   19    male  Diamond Hurbour    45    88    85  72.666667

# %%
print(df.query("Average > 90"))
# Out:
#     Name  Age  Gender     City  Sub1  Sub2  Sub3    Average
# 2  bheem   17  Female  naihati    96    92    98  95.333333

# %%
print(df["Name"].duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Name, dtype: bool
