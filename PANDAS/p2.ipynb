# %%
import pandas as pd

# %%
s=pd.Series(["!",2,4567,'Tanmoy',"Pikachu"])

# %%
print(s)

# %%
s=pd.Series([1,2,9,58,5,82],index=['a','b','c','d','k','q'])
print(s)

# %%
d={"a":1,"b":2,"c":3}
ser=pd.Series(data=d)
print(ser)

# %%
d={"a":1,"b":2,"c":3}
ser=pd.Series(data=d,index=["a","b","c"])
print(ser)

# %%
d={"a":1,"b":2,"c":3}
ser=pd.Series(d,index=["a","B","c"])
print(ser)

# %%
print(pd.__version__)

# %%
X=pd.Series([10,20,30,41,450,785])
print(X)

# %%
y=pd.Series([78,95,9752,84,546,78], index=['T','A','N','M','O','Y'])
print(y)

# %%
y=pd.Series([7+8j,'95',97.52,84,546,78], index=['T','A','N','M','O','Y'])
print(y)

# %%
ages_ditc= pd.Series({'Tanmoy':25,'Ranjan':45,'Gulu':12})
print(ages_ditc)

# %%
ages_dict = {'Alice': 25, 'Bob': 30, 'Charlie': 28}
s = pd.Series(ages_dict)
print(s)

# %% [markdown]
# # Indexing & Slicing

# %%
s=pd.Series(10,index=['a','b','c','d','e'])
print(s)

# %%
calories={
    "Day1":1750,
    "Day2":2500,
    "Day3":1700
}
serise=pd.Series(calories)
print(serise)
serise.loc["Day2"]+=500
print(serise)

# %%
s=pd.Series([45,559,54541,84512],index=['a',89,'tanmoy',4+7j])
print(s)

# %%
y=pd.Series([7+8j,'95',97.52,84,546,78], index=['T','A','N','M','O','Y'])
y.name='marks'
print(y)
print(y['T'])
print(y.loc['A':'O'])
y.loc['N']=234
print(y)

# %%
print(y.iloc[0])
print(y.iloc[0:3])
print(y.iloc[:4])

# %%
Ages=pd.Series([25,46,78,69],index=['ram','gun','kol','jonny'])
old=Ages[Ages>28]
print(old)

# %% [markdown]
# # Pandas Attributes

# %%
print(y.index)
print(y.values)
print(y.dtypes)
print(y.dtype)
print(y.size)
print(y.shape)

# %%
z=pd.Series([7,95,97.52,84,546,78], index=['T','A','N','M','O','Y'])
print(z)

# %%
print(z.index)
print(z.values)
print(z.dtypes)
print(z.dtype)
print(z.size)
print(z.shape)

# %%
g=pd.Series(['ant','cat','jerry'])
print(g)
print('------------------------')
print(g.T)
idx=pd.Index([1,2,3])
print(idx.T)

# %%
v=pd.Series([78,5.787,75.9,-7,-53.4,-78+5j,101])
s=pd.Series([7,-95,97.52,84,-54.6,78])
print(v.abs())
print('-----------------')
print(s.abs())

# %% [markdown]
# # Dataframe

# %%
data={
    "Name":["Spongbob","Bhalo","Bulbula"],
    "Age":[20,40,12]
}
df=pd.DataFrame(data,index=["Employee 1","Employee 2","Employee 3"])
print(df)
# Out:
#                 Name  Age
# Employee 1  Spongbob   20
# Employee 2     Bhalo   40
# Employee 3   Bulbula   12

# %% [markdown]
# ##### Selecting a single row

# %%
print(df.loc["Employee 1"])
print(df.iloc[0:3])
# Out:
# Name    Spongbob
# Age           20
# Name: Employee 1, dtype: object
#                 Name  Age
# Employee 1  Spongbob   20
# Employee 2     Bhalo   40
# Employee 3   Bulbula   12

# %% [markdown]
# #### Add a new column

# %%
df["Job"]=["Cook",None,"Cashier"]
print(df)
# Out:
#                 Name  Age      Job
# Employee 1  Spongbob   20     Cook
# Employee 2     Bhalo   40      NaN
# Employee 3   Bulbula   12  Cashier

# %% [markdown]
# #### Add a new Row

# %%
# new_row =pd.DataFrame([{"Name":"Sandy","Age":23,"Job":"Driver"}])
# df=pd.concat([df, new_row])
# print(df)

# %% [markdown]
# #### Importing csv and json file

# %%
df=pd.read_csv("Hospital ER.csv")
print(df.to_string())
# Out:
#                   date   patient_id patient_gender  patient_age  patient_sat_score patient_first_inital      patient_last_name                   patient_race  patient_admin_flag  patient_waittime department_referral
# 0     20-03-2020 08:47  145-39-5406              M           69               10.0                    H              Glasspool                          White               False                39    General Practice
# 1     15-06-2020 11:29  316-34-3057              M            4                NaN                    X                Methuen  Native American/Alaska Native                True                27    General Practice
# 2     20-06-2020 09:13  897-46-3852              F           56                9.0                    P              Schubuser               African American                True                55    General Practice
# ...

# %% [markdown]
# # -------------------------------

# %%
data={
    'Name':["Amit","Baja","Sagar"],
    'Roll':[20,52,84]
}
x=pd.DataFrame(data)
print(x)

# %% [markdown]
# ### Handling Missing Value

# %%
data = {
    'Name':['Amit','Priya','Rohit',None,'Amit'],
    'Roll':[20,52,84,56,89],
    'Mark':[78,None,90,75,85]
}
df=pd.DataFrame(data)
print("Original dataframe :- \n",df)
# print(df.dtype)

# %% [markdown]
# #### Data Cleaning

# %%
print("This is for isnull: \n",df.isnull()) 
print("This is for notnull: \n",df.notnull())

# %%
print('Count the missing  values  per columns is : \n',df.isnull().sum())
print('Count total missing  values  in df is :',df.isnull().sum().sum())

# %%
#test for this

# %% [markdown]
# ##### Filling Missing Values

# %%
print(df.fillna('Unknown'))
df['Mark']=df['Mark'].fillna(56)
# df['Marks']=df['Marks'].fillna(df['Mark'].mean())
print(df)

# %% [markdown]
# # Column Selection

# %%
print(df['Name'])
print(df['Mark'])

# %%
print
